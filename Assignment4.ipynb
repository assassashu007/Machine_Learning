# %%
#Question 1:
import pandas as pd
dict1={"Name"     : "Ashutosh Rawat",
      "Age"      : "23",
      "E.Mail"   : "assassashu007@gmail.com",
      "Phone No.": "8171248562"}
data= pd.DataFrame(dict1, index=[1])
data
# Out:
#              Name Age                   E.Mail   Phone No.
# 1  Ashutosh Rawat  23  assassashu007@gmail.com  8171248562

# %%
dict2={"Name"     : "Kushagra Rana",
      "Age"      : "22",
      "E.Mail"   : "k_ran26@yahoo.in",
      "Phone No.": "9997806036"}
data =pd.DataFrame([dict1,dict2], index=[1,2])
data
# Out:
#   Age                   E.Mail            Name   Phone No.
# 1  23  assassashu007@gmail.com  Ashutosh Rawat  8171248562
# 2  22         k_ran26@yahoo.in   Kushagra Rana  9997806036

# %%
#Question 2:
import os
path = os.getcwd()+"\dataset\weather.csv"
path
# Out:
# 'C:\\Users\\hp\\dataset\\weather.csv'

# %%
dat = pd.read_csv(path)

# %%
dat.head(5)
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0      8.0     24.3       0.0          3.4       6.3          NW
# 1     14.0     26.9       3.6          4.4       9.7         ENE
# 2     13.7     23.4       3.6          5.8       3.3          NW
# 3     13.3     15.5      39.8          7.2       9.1          NW
# 4      7.6     16.1       2.8          5.6      10.6         SSE
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am     ...       \
# 0           30.0         SW         NW           6.0     ...
# 1           39.0          E          W           4.0     ...
# 2           85.0          N        NNE           6.0     ...
# 3           54.0        WNW          W          30.0     ...
# 4           50.0        SSE        ESE          20.0     ...
#
#    Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  \
# 0           29       1019.7       1015.0         7         7     14.4
# ...

# %%
dat.head(10)
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0      8.0     24.3       0.0          3.4       6.3          NW
# 1     14.0     26.9       3.6          4.4       9.7         ENE
# 2     13.7     23.4       3.6          5.8       3.3          NW
# 3     13.3     15.5      39.8          7.2       9.1          NW
# 4      7.6     16.1       2.8          5.6      10.6         SSE
# 5      6.2     16.9       0.0          5.8       8.2          SE
# 6      6.1     18.2       0.2          4.2       8.4          SE
# 7      8.3     17.0       0.0          5.6       4.6           E
# 8      8.8     19.5       0.0          4.0       4.1           S
# 9      8.4     22.8      16.2          5.4       7.7           E
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am     ...       \
# 0           30.0         SW         NW           6.0     ...
# 1           39.0          E          W           4.0     ...
# ...

# %%
dat.corr()
# Out:
#                 MinTemp   MaxTemp  Rainfall  Evaporation  Sunshine  \
# MinTemp        1.000000  0.752471  0.201939     0.649930  0.035711
# MaxTemp        0.752471  1.000000 -0.073560     0.690026  0.452064
# Rainfall       0.201939 -0.073560  1.000000    -0.007293 -0.150990
# Evaporation    0.649930  0.690026 -0.007293     1.000000  0.318025
# Sunshine       0.035711  0.452064 -0.150990     0.318025  1.000000
# WindGustSpeed  0.218020  0.109672  0.096190     0.288477  0.095843
# WindSpeed9am   0.127542 -0.216814  0.219637     0.068929 -0.064522
# WindSpeed3pm  -0.065922 -0.167873  0.056008     0.048601  0.072573
# Humidity9am   -0.207897 -0.359602  0.150109    -0.519587 -0.499017
# Humidity3pm   -0.040709 -0.533327  0.289013    -0.391780 -0.759429
# Pressure9am   -0.501707 -0.290883 -0.331581    -0.381906  0.006276
# Pressure3pm   -0.498007 -0.379394 -0.250218    -0.391093 -0.036201
# Cloud9am       0.215776 -0.175730  0.180046    -0.106007 -0.681092
# ...

# %%
dat.var()
# Out:
# MinTemp           36.310264
# MaxTemp           44.763000
# Rainfall          17.857382
# Evaporation        7.125603
# Sunshine          12.120962
# WindGustSpeed    170.558563
# WindSpeed9am      63.233174
# WindSpeed3pm      78.446388
# Humidity9am      172.582297
# Humidity3pm      283.954428
# Pressure9am       44.705425
# Pressure3pm       41.853426
# Cloud9am           8.738708
# Cloud3pm           7.108983
# Temp9am           31.706271
# Temp3pm           44.094195
# RISK_MM           17.857382
# dtype: float64

# %%
dat.cov()
# Out:
#                  MinTemp    MaxTemp   Rainfall  Evaporation   Sunshine  \
# MinTemp        36.310264  30.336393   5.142132    10.454234   0.748488
# MaxTemp        30.336393  44.763000  -2.079734    12.323556  10.557882
# Rainfall        5.142132  -2.079734  17.857382    -0.082267  -2.206003
# Evaporation    10.454234  12.323556  -0.082267     7.125603   2.957679
# Sunshine        0.748488  10.557882  -2.206003     2.957679  12.120962
# WindGustSpeed  17.141617   9.586647   5.321497    10.057585   4.380600
# WindSpeed9am    6.108382 -11.530989   7.429987     1.461235  -1.802766
# WindSpeed3pm   -3.518280  -9.947804   2.096280     1.149067   2.244656
# Humidity9am   -16.457404 -31.606722   8.333235   -18.220779 -22.857018
# Humidity3pm    -4.133586 -60.128087  20.580277   -17.622885 -44.487625
# Pressure9am   -20.213661 -13.012400  -9.368695    -6.816280   0.145798
# Pressure3pm   -19.414025 -16.421592  -6.840570    -6.753926  -0.813373
# ...

# %%
dat.tail(5)
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 361      9.0     30.7       0.0          7.6      12.1         NNW
# 362      7.1     28.4       0.0         11.6      12.7           N
# 363     12.5     19.9       0.0          8.4       5.3         ESE
# 364     12.5     26.9       0.0          5.0       7.1          NW
# 365     12.3     30.2       0.0          6.0      12.6          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am     ...       \
# 361           76.0        SSE         NW           7.0     ...
# 362           48.0        NNW        NNW           2.0     ...
# 363           43.0        ENE        ENE          11.0     ...
# 364           46.0        SSW        WNW           6.0     ...
# 365           78.0         NW        WNW          31.0     ...
#
#      Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  \
# 361           15       1016.1       1010.8         1         3     20.4
# ...

# %%
dat.loc[1:1]
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 1     14.0     26.9       3.6          4.4       9.7         ENE
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am     ...       \
# 1           39.0          E          W           4.0     ...
#
#    Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  \
# 1           36       1012.4       1008.4         5         3     17.5
#
#    Temp3pm  RainToday  RISK_MM RainTomorrow
# 1     25.7        Yes      3.6          Yes
#
# [1 rows x 22 columns]
